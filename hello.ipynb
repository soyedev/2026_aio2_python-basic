# %%
# 변수 선언
name = "alice"
age = int(input("나이를 입력하세요: "))
print(f"이름: {name}, 나이: {age}")
# Out:
# 이름: alice, 나이: 22

# %%
print(1)    
print(2)
print(3)
# Out:
# 10

# %%
# docstring
"""This is a simple docstring for the script."""

# 문자열
"hello"
'hi'

"""hel
lo"""

# %%
def calculate_sum(a, b):
    result = a + b
    return result


result = calculate_sum(3, 5)

if result > 0:
    print("양수입니다")
# Out:
# 양수입니다

# %%
val_i = 1

print(val_i)
# Out:
# 1

# %%
def f_a():
    return

f_a()
